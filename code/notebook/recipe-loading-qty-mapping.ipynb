# %%
import requests
import json
import re
import pandas as pd 
import numpy as np
from recipe_loading import *
from qty_mapping import *
from sentence_transformers import SentenceTransformer
from ranker import *
from preprocessor import *
import joblib

# %% [markdown]
# The steps followed here are:
#
# 1) Load 1m recipe
# 2) Standardise the units
# 3) Load density info
# 4) Calculate the required amount of each ingredient

# %%
# from zipfile import ZipFile
# with ZipFile('../../data/layer1.zip') as myzip:
#     with myzip.open(myzip.namelist()[0]) as myfile:
#         recipe_str = myfile.read()
# recipe = json.loads(recipe_str)

# %%
filepath = "/Users/chahaksethi/Desktop/Target/data/1m_recipe/recipe1M_layers/layer1.json"
op_file_path = "../../../Data/ing_density.csv"

# %%
with open(filepath) as json_data:
    recipe_tot = json.load(json_data)

# %%
unit_abbreviation = { 'tbsp' : ["tablespoon"],
                      'tsp' : ['teaspoon'],
                     'ml' : ['milliliter'],
                     'cup' : ['cups','cup'],
                     'oz' : ['ounces','oz', 'ounce']
    
}

# %%
# loading recipe
dict_ingredients= recipe_load(n=2, recipe=recipe_tot)
df_combined_ing = pd.DataFrame.from_dict(dict_ingredients)
df_combined_ing
# Out:
#                                ingredient        unit quantity
# 0                                   penne     ounces         6
# 1          Beechers Flagship Cheese Sauce       cups         2
# 2                                 Cheddar      ounce         1
# 3                          Gruyere cheese      ounce         1
# 4                   chipotle chili powder   teaspoon       1/2
# 5                         unsalted butter        cup       1/4
# 6                       all-purpose flour        cup       1/3
# 7                                    milk       cups         3
# 8                         semihard cheese     ounces        14
# 9                         semisoft cheese     ounces         2
# 10                            kosher salt   teaspoon       1/2
# 11                  chipotle chili powder   teaspoon       1/2
# 12                          garlic powder   teaspoon       1/8
# 13                         elbow macaroni        cup         1
# 14                  cubed American cheese        cup         1
# 15                          sliced celery        cup       1/2
# 16                    minced green pepper        cup       1/2
# 17                         minced pimento       tbsp         3
# 18  mayonnaise or possibly salad dressing        cup       1/2
# 19                                vinegar       tbsp         1
# 20                                   salt   teaspoon       3/4
# 21                          dry dill weed   teaspoon       1/2

# %%
#converting qty from fraction to float
df_combined_ing['quantity'] = df_combined_ing['quantity'].apply(convert_fraction)
df_combined_ing['quantity'] = df_combined_ing['quantity'].apply(float)

# %%
#normalising units
qty = Qty_normal_map(unit_abbreviation = unit_abbreviation, op_file_path= op_file_path)
combined_ingredient_df=qty.normalize_units(df_combined_ing)
combined_ingredient_df
# Out:
#                                ingredient        unit   quantity  \
# 0                                   penne     ounces    6.000000
# 1          Beechers Flagship Cheese Sauce       cups    2.000000
# 2                                 Cheddar      ounce    1.000000
# 3                          Gruyere cheese      ounce    1.000000
# 4                   chipotle chili powder   teaspoon    0.500000
# 5                         unsalted butter        cup    0.250000
# 6                       all-purpose flour        cup    0.333333
# 7                                    milk       cups    3.000000
# 8                         semihard cheese     ounces   14.000000
# 9                         semisoft cheese     ounces    2.000000
# 10                            kosher salt   teaspoon    0.500000
# 11                  chipotle chili powder   teaspoon    0.500000
# 12                          garlic powder   teaspoon    0.125000
# 13                         elbow macaroni        cup    1.000000
# 14                  cubed American cheese        cup    1.000000
# 15                          sliced celery        cup    0.500000
# 16                    minced green pepper        cup    0.500000
# 17                         minced pimento       tbsp    3.000000
# 18  mayonnaise or possibly salad dressing        cup    0.500000
# 19                                vinegar       tbsp    1.000000
# 20                                   salt   teaspoon    0.750000
# 21                          dry dill weed   teaspoon    0.500000
#
#    normalized_unit  Volume_in_ml
# 0               oz       180.000
# 1              cup       450.000
# 2               oz        30.000
# 3               oz        30.000
# 4              tsp         2.500
# 5              cup        56.250
# 6              cup        75.000
# 7              cup       675.000
# 8               oz       420.000
# 9               oz        60.000
# 10             tsp         2.500
# 11             tsp         2.500
# 12             tsp         0.625
# 13             cup       225.000
# 14             cup       225.000
# 15             cup       112.500
# 16             cup       112.500
# 17            tbsp         0.000
# 18             cup       112.500
# 19            tbsp         0.000
# 20             tsp         3.750
# 21             tsp         2.500

# %%
# required for multiple recipes - combining qty
combined_ingredient_df = df_combined_ing.groupby(by=['ingredient', 'normalized_unit'], 
                                               as_index = False)\
                                      .agg({'quantity': 'sum', 'Volume_in_ml': 'sum'})

# %%
#using density info calculating required ounces for each ingredient
final_df = qty.req_oz_recipe(combined_ingredient_df)
# Out:
# /Users/chahaksethi/Desktop/Target/target_recipe_project/code/notebook/qty_mapping.py:54: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   combined_ingredient_df['standard_vol'],combined_ingredient_df['standard_weight_gm'],\

# %%
final_df
# Out:
#                                ingredient normalized_unit   quantity  \
# 0          Beechers Flagship Cheese Sauce             cup   2.000000
# 1                                 Cheddar              oz   1.000000
# 2                          Gruyere cheese              oz   1.000000
# 3                       all-purpose flour             cup   0.333333
# 4                   chipotle chili powder             tsp   1.000000
# 5                   cubed American cheese             cup   1.000000
# 6                           dry dill weed             tsp   0.500000
# 7                          elbow macaroni             cup   1.000000
# 8                           garlic powder             tsp   0.125000
# 9                             kosher salt             tsp   0.500000
# 10  mayonnaise or possibly salad dressing             cup   0.500000
# 11                                   milk             cup   3.000000
# 12                    minced green pepper             cup   0.500000
# 13                         minced pimento            tbsp   3.000000
# 14                                  penne              oz   6.000000
# 15                                   salt             tsp   0.750000
# 16                        semihard cheese              oz  14.000000
# 17                        semisoft cheese              oz   2.000000
# 18                          sliced celery             cup   0.500000
# 19                        unsalted butter             cup   0.250000
# 20                                vinegar            tbsp   1.000000
#
#     Volume_in_ml  standard_vol  standard_weight_gm standard_unit  req_oz
# 0        450.000           NaN                 NaN                16.000
# 1         30.000           1.0                 5.0          tbsp   1.000
# 2         30.000           1.0               108.0           cup   1.000
# 3         75.000           1.0               125.0           cup   1.470
# 4          5.000           1.0                 8.0          tbsp   0.094
# 5        225.000           NaN                 NaN                 8.000
# 6          2.500           5.0                 1.0        sprigs   0.000
# 7        225.000           1.0               230.0           cup   8.113
# 8          0.625           1.0                 9.7          tbsp   0.014
# 9          2.500           1.0                40.4                 0.000
# 10       112.500           1.0               235.0           cup   4.145
# 11       675.000           1.0               244.0           cup  25.820
# 12       112.500           1.0               155.0           cup   2.734
# 13         0.000           1.0                 1.0         slice   0.000
# 14       180.000           1.0               140.0           cup   6.000
# 15         3.750           1.0               100.0           cup   0.059
# 16       420.000           NaN                 NaN                14.000
# 17        60.000           NaN                 NaN                 2.000
# 18       112.500           1.0               120.0           cup   2.116
# 19        56.250           1.0               143.0         large   2.000
# 20         0.000           1.0                15.0    tablespoon   0.000

# %%
# Set input file directory
ip_file_dir = "../../data/"

# Get grocery product hierarchy information
group10 = pd.read_csv(os.path.join(ip_file_dir, 
                                   'group10_header.csv'),
                      sep='\t', 
                      low_memory=False)

# Get scraped information for the above products
products = pd.read_csv(os.path.join(ip_file_dir,
                                    'scraped/products.csv'))

# Merge scraped information into the hierarchy table
group10 = pd.merge(group10, products, 
                   how = 'left', on = 'tcin')

# Preprocess the table
group10 = preprocess_df(group10)

# %%
# Get list of preprocessed product titles
product_titles = group10['title_modified'].values
# Preprocess recipe ingredients
final_df['ingredient'] = preprocess(final_df['ingredient'])

# %%
final_df
# Out:
#                                ingredient normalized_unit   quantity  \
# 0          beechers flagship cheese sauce             cup   2.000000
# 1                                 cheddar              oz   1.000000
# 2                          gruyere cheese              oz   1.000000
# 3                       all purpose flour             cup   0.333333
# 4                   chipotle chili powder             tsp   1.000000
# 5                   cubed american cheese             cup   1.000000
# 6                           dry dill weed             tsp   0.500000
# 7                          elbow macaroni             cup   1.000000
# 8                           garlic powder             tsp   0.125000
# 9                             kosher salt             tsp   0.500000
# 10  mayonnaise or possibly salad dressing             cup   0.500000
# 11                                   milk             cup   3.000000
# 12                    minced green pepper             cup   0.500000
# 13                         minced pimento            tbsp   3.000000
# 14                                  penne              oz   6.000000
# 15                                   salt             tsp   0.750000
# 16                        semihard cheese              oz  14.000000
# 17                        semisoft cheese              oz   2.000000
# 18                          sliced celery             cup   0.500000
# 19                        unsalted butter             cup   0.250000
# 20                                vinegar            tbsp   1.000000
#
#     Volume_in_ml  standard_vol  standard_weight_gm standard_unit  req_oz
# 0        450.000           NaN                 NaN                16.000
# 1         30.000           1.0                 5.0          tbsp   1.000
# 2         30.000           1.0               108.0           cup   1.000
# 3         75.000           1.0               125.0           cup   1.470
# 4          5.000           1.0                 8.0          tbsp   0.094
# 5        225.000           NaN                 NaN                 8.000
# 6          2.500           5.0                 1.0        sprigs   0.000
# 7        225.000           1.0               230.0           cup   8.113
# 8          0.625           1.0                 9.7          tbsp   0.014
# 9          2.500           1.0                40.4                 0.000
# 10       112.500           1.0               235.0           cup   4.145
# 11       675.000           1.0               244.0           cup  25.820
# 12       112.500           1.0               155.0           cup   2.734
# 13         0.000           1.0                 1.0         slice   0.000
# 14       180.000           1.0               140.0           cup   6.000
# 15         3.750           1.0               100.0           cup   0.059
# 16       420.000           NaN                 NaN                14.000
# 17        60.000           NaN                 NaN                 2.000
# 18       112.500           1.0               120.0           cup   2.116
# 19        56.250           1.0               143.0         large   2.000
# 20         0.000           1.0                15.0    tablespoon   0.000

# %%
recipe_ingredients = list(final_df['ingredient'].values)

# %%
lm = SentenceTransformer('all-MiniLM-L6-v2')

# %%
tr = TransformerRanker(model=lm, product_ids=group10['tcin'])
product_title_embeddings = joblib.load('../../data/lm_embeddings')
tr.load_embeddings(product_title_embeddings)

# %%
# Ranked list of product tcin matches for each ingredient - Returns a list of lists 
ranked_match = tr.rank_products_recipe(recipe_ingredients)

# %%
rslt_df = group10[['title', 'tcin', 'short_desc','price','net_content_quantity_unit_of_measure', 'net_content_quantity_value', 'package_weight_unit_of_measure','package_weight']]
final_rslt_df=pd.DataFrame()

for i in range(len(ranked_match)):
    rslt_inter = rslt_df.loc[group10['tcin'].isin(ranked_match[i])] 
    ing = recipe_ingredients[i]
    length = min(len(ranked_match[i]),9)
    for n in range(0,length):
        for j, row in rslt_inter.iterrows():
            if row.tcin == ranked_match[i][n] :
                rslt_inter.loc[j,'rank']=n+1
                rslt_inter.loc[j,'ingredient']=ing
                break
       
    rslt_inter_n=rslt_inter.sort_values('rank')[0:9] 
    final_rslt_df= pd.concat([final_rslt_df,rslt_inter_n], ignore_index=True)
# Out:
# /Users/chahaksethi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/chahaksethi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
#matching target database with recipe 
join_df = pd.merge(final_rslt_df, final_df, 
                   how = 'left', on = 'ingredient')

# %%
#calculating recommended quantity
rec_df = qty.recommended_quantity(join_df)
df = rec_df.sort_values(by=['recommended_qty', 'price'])

# %%
df[df['ingredient']=='all purpose flour']
# df[df['ingredient']=='milk']
# Out:
#                                                 title      tcin  \
# 29  Unbleached All Purpose Flour - 5lbs - Good & G...  77640693
# 28          All Purpose Flour - 5lbs - Market Pantry™  13474783
# 30           Whole Wheat Flour - 5LB - Good & Gather™  78206460
# 27                Gold Medal All Purpose Flour - 2lbs  13016243
# 33             Mission 6" Flour Tortillas - 23oz/20ct  14770774
# 34  King Arthur Flour Unbleached White Whole Wheat...  14776414
# 32         King Arthur Flour Whole Wheat Flour - 5lbs  14777566
# 35  King Arthur Flour Unbleached All-Purpose Flour...  14777928
# 31               Organic Flour - 5LB - Good & Gather™  77640459
#
#                           short_desc  price  \
# 29    GG Flour UNBLCHD ALL PRPSE 5LB   1.69
# 28   MP FLOUR MP ALL PURPOSE FLR 5LB   1.79
# 30          GG Flour WHOLE WHEAT 5LB   2.49
# 27  GOLD MEDAL ALL PURPOSE FLOUR 2LB   2.99
# 33      MISSION MSN 23OZ 20CT 6" TRT   4.19
# 34     KING ARTHUR 5LB KAF WWW FLOUR   4.49
# 32      KING ARTHUR 5LB KAF WW FLOUR   4.69
# 35      KING ARTHUR 5LB KAF AP FLOUR   5.29
# 31        GG FLOUR ORGANIC FLOUR 5LB   5.49
#
#    net_content_quantity_unit_of_measure  net_content_quantity_value  \
# 29                                POUND                         5.0
# 28                                POUND                         5.0
# 30                                POUND                         5.0
# 27                                POUND                         2.0
# 33                                OUNCE                        23.0
# 34                                POUND                         5.0
# 32                                POUND                         5.0
# 35                                POUND                         5.0
# 31                                POUND                         5.0
#
#    package_weight_unit_of_measure  package_weight  rank         ingredient  \
# 29                          POUND           5.120   3.0  all purpose flour
# 28                          POUND           5.660   2.0  all purpose flour
# 30                          POUND           5.000   4.0  all purpose flour
# 27                          POUND           2.020   1.0  all purpose flour
# 33                          POUND           1.438   7.0  all purpose flour
# 34                          POUND           5.060   8.0  all purpose flour
# 32                          POUND           5.000   6.0  all purpose flour
# 35                          POUND           5.150   9.0  all purpose flour
# 31                          POUND           5.200   5.0  all purpose flour
#
#    normalized_unit  quantity  Volume_in_ml  standard_vol  standard_weight_gm  \
# 29             cup  0.333333          75.0           1.0               125.0
# 28             cup  0.333333          75.0           1.0               125.0
# 30             cup  0.333333          75.0           1.0               125.0
# 27             cup  0.333333          75.0           1.0               125.0
# 33             cup  0.333333          75.0           1.0               125.0
# 34             cup  0.333333          75.0           1.0               125.0
# 32             cup  0.333333          75.0           1.0               125.0
# 35             cup  0.333333          75.0           1.0               125.0
# 31             cup  0.333333          75.0           1.0               125.0
#
#    standard_unit  req_oz  product_qty_oz_ct  recommended_qty
# 29           cup    1.47             81.920              1.0
# 28           cup    1.47             90.560              1.0
# 30           cup    1.47             80.000              1.0
# 27           cup    1.47             32.320              1.0
# 33           cup    1.47             23.008              1.0
# 34           cup    1.47             80.960              1.0
# 32           cup    1.47             80.000              1.0
# 35           cup    1.47             82.400              1.0
# 31           cup    1.47             83.200              1.0
