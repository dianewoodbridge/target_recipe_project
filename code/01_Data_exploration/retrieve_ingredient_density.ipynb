# %% [markdown]
# # Data from USDA FDC :
#
# https://fdc.nal.usda.gov/index.html

# %% [markdown]
# USDA :
#     API KEY - 6QckmmkUv58RO4eu9eiXKUD1a0L60mSjTnHfa036
#
#     Ex.
#     https://api.nal.usda.gov/fdc/v1/foods/search?query=apple&pageSize=2&api_key=6QckmmkUv58RO4eu9eiXKUD1a0L60mSjTnHfa036

# %%
import requests

# %%
api_key = "6QckmmkUv58RO4eu9eiXKUD1a0L60mSjTnHfa036"
ingredient = "salt"

# %%
def search_usda_food_with_fdcid(fdcid):
    '''
    given fdc id, return the detailed info
    '''
    url = "https://api.nal.usda.gov/fdc/v1/food/{}?api_key={}".format(fdcid, api_key)
    response = requests.request("GET", url)

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    
    return response.json()

# %%
def search_fdcid(ingredient):
    '''
    Return the fdc id of the search for the first one with food portions
    '''
    ingredient = ingredient.replace(" ","%20")
    url = "https://api.nal.usda.gov/fdc/v1/foods/search?query={}&model=foodPortion&api_key=6QckmmkUv58RO4eu9eiXKUD1a0L60mSjTnHfa036"\
          .format(ingredient)
    response = requests.request("GET", url)

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    
    for food in response.json().get("foods"):
        fdc_id = food.get("fdcId")
        if( len(search_usda_food_with_fdcid(fdc_id).get("foodPortions"))> 0 ):
            return fdc_id

# %%
def retrieve_food_portions(json_data):
    '''
    returns gramWeight per volume unit including tsp/tbsp/cup/
    '''
    return json_data.get("foodPortions")

# %%
fdcid = search_fdcid(ingredient)
json_data = search_usda_food_with_fdcid(fdcid)

# %%
fdcid
# Out:
# 1100545

# %%
json_data
# Out:
# {'wweiaFoodCategory': {'wweiaFoodCategoryCode': 2804,
#   'wweiaFoodCategoryDescription': 'Nuts and seeds'},
#  'description': 'Pecans, salted',
#  'foodAttributes': [{'id': 996264,
#    'value': 'Nuts and seeds',
#    'name': 'WWEIA Category description',
#    'foodAttributeType': {'id': 999,
#     'name': 'Attribute',
#     'description': 'Generic attributes'}},
#   {'id': 988073,
#    'value': '2804',
#    'name': 'WWEIA Category number',
#    'foodAttributeType': {'id': 999,
#     'name': 'Attribute',
#     'description': 'Generic attributes'}},
#   {'id': 972061,
#    'value': 'sea salt',
#    'sequenceNumber': 6,
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'}},
#   {'id': 972060,
#    'value': 'not coated',
#    'sequenceNumber': 5,
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'}},
#   {'id': 972058,
#    'value': 'NS as to salt',
#    'sequenceNumber': 3,
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'}},
#   {'id': 972057,
#    'value': 'lightly salted',
#    'sequenceNumber': 2,
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'}},
#   {'id': 972056,
#    'value': 'plain',
#    'sequenceNumber': 1,
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'}},
#   {'id': 972059,
#    'value': 'roasted',
#    'sequenceNumber': 4,
#    'foodAttributeType': {'id': 1001,
#     'name': 'Additional Description',
#     'description': 'Additional descriptions for the food.'}}],
#  'foodCode': '42112200',
#  'inputFoods': [{'id': 90286,
#    'foodDescription': 'Nuts, pecans',
#    'ingredientDescription': 'Nuts, pecans',
#    'ingredientWeight': 97.0,
#    'portionCode': '0',
#    'portionDescription': 'NONE',
#    'sequenceNumber': 1,
#    'ingredientCode': 12142,
#    'unit': 'GM',
#    'amount': 97.0},
#   {'id': 90287,
#    'foodDescription': 'Vegetable oil, NFS',
#    'ingredientDescription': 'Vegetable oil, NFS',
#    'ingredientWeight': 3.0,
#    'portionCode': '0',
#    'portionDescription': 'NONE',
#    'sequenceNumber': 2,
#    'ingredientCode': 82101000,
#    'unit': 'GM',
#    'amount': 3.0,
#    'inputFood': {'fdcId': 1103855,
#     'description': 'Vegetable oil, NFS',
#     'publicationDate': '10/30/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Survey',
#     'totalRefuse': 0,
#     'dataType': 'Survey (FNDDS)'}},
#   {'id': 90288,
#    'foodDescription': 'Salt, table, iodized',
#    'ingredientDescription': 'Salt, table, iodized',
#    'ingredientWeight': 1.0,
#    'portionCode': '0',
#    'portionDescription': 'NONE',
#    'sequenceNumber': 3,
#    'ingredientCode': 2047,
#    'unit': 'GM',
#    'amount': 1.0}],
#  'startDate': '1/1/2017',
#  'endDate': '12/31/2018',
#  'foodComponents': [],
#  'foodClass': 'Survey',
#  'fdcId': 1100545,
#  'publicationDate': '10/30/2020',
#  'foodNutrients': [{'nutrient': {'id': 2045,
#     'number': '951',
#     'name': 'Proximates',
#     'rank': 50,
#     'unitName': 'g'},
#    'type': 'FoodNutrient'},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1051,
#     'number': '255',
#     'name': 'Water',
#     'rank': 100,
#     'unitName': 'g'},
#    'id': 13072498,
#    'amount': 3.38},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1008,
#     'number': '208',
#     'name': 'Energy',
#     'rank': 300,
#     'unitName': 'kcal'},
#    'id': 13072496,
#    'amount': 690.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1003,
#     'number': '203',
#     'name': 'Protein',
#     'rank': 600,
#     'unitName': 'g'},
#    'id': 13072493,
#    'amount': 8.81},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1004,
#     'number': '204',
#     'name': 'Total lipid (fat)',
#     'rank': 800,
#     'unitName': 'g'},
#    'id': 13072494,
#    'amount': 72.09},
#   {'nutrient': {'id': 2039,
#     'number': '956',
#     'name': 'Carbohydrates',
#     'rank': 1100,
#     'unitName': 'g'},
#    'type': 'FoodNutrient'},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1005,
#     'number': '205',
#     'name': 'Carbohydrate, by difference',
#     'rank': 1110,
#     'unitName': 'g'},
#    'id': 13072495,
#    'amount': 13.31},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1079,
#     'number': '291',
#     'name': 'Fiber, total dietary',
#     'rank': 1200,
#     'unitName': 'g'},
#    'id': 13072502,
#    'amount': 9.2},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 2000,
#     'number': '269',
#     'name': 'Sugars, total including NLEA',
#     'rank': 1510,
#     'unitName': 'g'},
#    'id': 13072501,
#    'amount': 3.81},
#   {'nutrient': {'id': 2043,
#     'number': '300',
#     'name': 'Minerals',
#     'rank': 5200,
#     'unitName': 'mg'},
#    'type': 'FoodNutrient'},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1087,
#     'number': '301',
#     'name': 'Calcium, Ca',
#     'rank': 5300,
#     'unitName': 'mg'},
#    'id': 13072503,
#    'amount': 68.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1089,
#     'number': '303',
#     'name': 'Iron, Fe',
#     'rank': 5400,
#     'unitName': 'mg'},
#    'id': 13072504,
#    'amount': 2.44},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1090,
#     'number': '304',
#     'name': 'Magnesium, Mg',
#     'rank': 5500,
#     'unitName': 'mg'},
#    'id': 13072505,
#    'amount': 116.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1091,
#     'number': '305',
#     'name': 'Phosphorus, P',
#     'rank': 5600,
#     'unitName': 'mg'},
#    'id': 13072506,
#    'amount': 266.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1092,
#     'number': '306',
#     'name': 'Potassium, K',
#     'rank': 5700,
#     'unitName': 'mg'},
#    'id': 13072507,
#    'amount': 394.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1093,
#     'number': '307',
#     'name': 'Sodium, Na',
#     'rank': 5800,
#     'unitName': 'mg'},
#    'id': 13072508,
#    'amount': 383.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1095,
#     'number': '309',
#     'name': 'Zinc, Zn',
#     'rank': 5900,
#     'unitName': 'mg'},
#    'id': 13072509,
#    'amount': 4.35},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1098,
#     'number': '312',
#     'name': 'Copper, Cu',
#     'rank': 6000,
#     'unitName': 'mg'},
#    'id': 13072510,
#    'amount': 1.152},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1103,
#     'number': '317',
#     'name': 'Selenium, Se',
#     'rank': 6200,
#     'unitName': 'µg'},
#    'id': 13072511,
#    'amount': 3.6},
#   {'nutrient': {'id': 2046,
#     'number': '952',
#     'name': 'Vitamins and Other Components',
#     'rank': 6250,
#     'unitName': 'g'},
#    'type': 'FoodNutrient'},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1162,
#     'number': '401',
#     'name': 'Vitamin C, total ascorbic acid',
#     'rank': 6300,
#     'unitName': 'mg'},
#    'id': 13072521,
#    'amount': 1.1},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1165,
#     'number': '404',
#     'name': 'Thiamin',
#     'rank': 6400,
#     'unitName': 'mg'},
#    'id': 13072522,
#    'amount': 0.634},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1166,
#     'number': '405',
#     'name': 'Riboflavin',
#     'rank': 6500,
#     'unitName': 'mg'},
#    'id': 13072523,
#    'amount': 0.125},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1167,
#     'number': '406',
#     'name': 'Niacin',
#     'rank': 6600,
#     'unitName': 'mg'},
#    'id': 13072524,
#    'amount': 1.121},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1175,
#     'number': '415',
#     'name': 'Vitamin B-6',
#     'rank': 6800,
#     'unitName': 'mg'},
#    'id': 13072525,
#    'amount': 0.202},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1177,
#     'number': '417',
#     'name': 'Folate, total',
#     'rank': 6900,
#     'unitName': 'µg'},
#    'id': 13072526,
#    'amount': 21.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1186,
#     'number': '431',
#     'name': 'Folic acid',
#     'rank': 7000,
#     'unitName': 'µg'},
#    'id': 13072530,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1187,
#     'number': '432',
#     'name': 'Folate, food',
#     'rank': 7100,
#     'unitName': 'µg'},
#    'id': 13072531,
#    'amount': 21.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1190,
#     'number': '435',
#     'name': 'Folate, DFE',
#     'rank': 7200,
#     'unitName': 'µg'},
#    'id': 13072532,
#    'amount': 21.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1180,
#     'number': '421',
#     'name': 'Choline, total',
#     'rank': 7220,
#     'unitName': 'mg'},
#    'id': 13072528,
#    'amount': 38.9},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1178,
#     'number': '418',
#     'name': 'Vitamin B-12',
#     'rank': 7300,
#     'unitName': 'µg'},
#    'id': 13072527,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1246,
#     'number': '578',
#     'name': 'Vitamin B-12, added',
#     'rank': 7340,
#     'unitName': 'µg'},
#    'id': 13072534,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1106,
#     'number': '320',
#     'name': 'Vitamin A, RAE',
#     'rank': 7420,
#     'unitName': 'µg'},
#    'id': 13072513,
#    'amount': 3.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1105,
#     'number': '319',
#     'name': 'Retinol',
#     'rank': 7430,
#     'unitName': 'µg'},
#    'id': 13072512,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1107,
#     'number': '321',
#     'name': 'Carotene, beta',
#     'rank': 7440,
#     'unitName': 'µg'},
#    'id': 13072514,
#    'amount': 28.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1108,
#     'number': '322',
#     'name': 'Carotene, alpha',
#     'rank': 7450,
#     'unitName': 'µg'},
#    'id': 13072515,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1120,
#     'number': '334',
#     'name': 'Cryptoxanthin, beta',
#     'rank': 7460,
#     'unitName': 'µg'},
#    'id': 13072518,
#    'amount': 9.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1122,
#     'number': '337',
#     'name': 'Lycopene',
#     'rank': 7530,
#     'unitName': 'µg'},
#    'id': 13072519,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1123,
#     'number': '338',
#     'name': 'Lutein + zeaxanthin',
#     'rank': 7560,
#     'unitName': 'µg'},
#    'id': 13072520,
#    'amount': 16.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1109,
#     'number': '323',
#     'name': 'Vitamin E (alpha-tocopherol)',
#     'rank': 7905,
#     'unitName': 'mg'},
#    'id': 13072516,
#    'amount': 1.69},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1242,
#     'number': '573',
#     'name': 'Vitamin E, added',
#     'rank': 7920,
#     'unitName': 'mg'},
#    'id': 13072533,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1114,
#     'number': '328',
#     'name': 'Vitamin D (D2 + D3)',
#     'rank': 8700,
#     'unitName': 'µg'},
#    'id': 13072517,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1185,
#     'number': '430',
#     'name': 'Vitamin K (phylloquinone)',
#     'rank': 8800,
#     'unitName': 'µg'},
#    'id': 13072529,
#    'amount': 6.9},
#   {'nutrient': {'id': 2044,
#     'number': '950',
#     'name': 'Lipids',
#     'rank': 9600,
#     'unitName': 'g'},
#    'type': 'FoodNutrient'},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1258,
#     'number': '606',
#     'name': 'Fatty acids, total saturated',
#     'rank': 9700,
#     'unitName': 'g'},
#    'id': 13072536,
#    'amount': 6.341},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1259,
#     'number': '607',
#     'name': 'SFA 4:0',
#     'rank': 9800,
#     'unitName': 'g'},
#    'id': 13072537,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1260,
#     'number': '608',
#     'name': 'SFA 6:0',
#     'rank': 9900,
#     'unitName': 'g'},
#    'id': 13072538,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1261,
#     'number': '609',
#     'name': 'SFA 8:0',
#     'rank': 10000,
#     'unitName': 'g'},
#    'id': 13072539,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1262,
#     'number': '610',
#     'name': 'SFA 10:0',
#     'rank': 10100,
#     'unitName': 'g'},
#    'id': 13072540,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1263,
#     'number': '611',
#     'name': 'SFA 12:0',
#     'rank': 10300,
#     'unitName': 'g'},
#    'id': 13072541,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1264,
#     'number': '612',
#     'name': 'SFA 14:0',
#     'rank': 10500,
#     'unitName': 'g'},
#    'id': 13072542,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1265,
#     'number': '613',
#     'name': 'SFA 16:0',
#     'rank': 10700,
#     'unitName': 'g'},
#    'id': 13072543,
#    'amount': 4.483},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1266,
#     'number': '614',
#     'name': 'SFA 18:0',
#     'rank': 10900,
#     'unitName': 'g'},
#    'id': 13072544,
#    'amount': 1.771},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1292,
#     'number': '645',
#     'name': 'Fatty acids, total monounsaturated',
#     'rank': 11400,
#     'unitName': 'g'},
#    'id': 13072556,
#    'amount': 40.429},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1275,
#     'number': '626',
#     'name': 'MUFA 16:1',
#     'rank': 11700,
#     'unitName': 'g'},
#    'id': 13072550,
#    'amount': 0.011},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1268,
#     'number': '617',
#     'name': 'MUFA 18:1',
#     'rank': 12100,
#     'unitName': 'g'},
#    'id': 13072545,
#    'amount': 40.207},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1277,
#     'number': '628',
#     'name': 'MUFA 20:1',
#     'rank': 12400,
#     'unitName': 'g'},
#    'id': 13072552,
#    'amount': 0.211},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1279,
#     'number': '630',
#     'name': 'MUFA 22:1',
#     'rank': 12500,
#     'unitName': 'g'},
#    'id': 13072554,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1293,
#     'number': '646',
#     'name': 'Fatty acids, total polyunsaturated',
#     'rank': 12900,
#     'unitName': 'g'},
#    'id': 13072557,
#    'amount': 21.981},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1269,
#     'number': '618',
#     'name': 'PUFA 18:2',
#     'rank': 13100,
#     'unitName': 'g'},
#    'id': 13072546,
#    'amount': 20.884},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1270,
#     'number': '619',
#     'name': 'PUFA 18:3',
#     'rank': 13900,
#     'unitName': 'g'},
#    'id': 13072547,
#    'amount': 1.098},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1276,
#     'number': '627',
#     'name': 'PUFA 18:4',
#     'rank': 14250,
#     'unitName': 'g'},
#    'id': 13072551,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1271,
#     'number': '620',
#     'name': 'PUFA 20:4',
#     'rank': 14700,
#     'unitName': 'g'},
#    'id': 13072548,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1278,
#     'number': '629',
#     'name': 'PUFA 2:5 n-3 (EPA)',
#     'rank': 15000,
#     'unitName': 'g'},
#    'id': 13072553,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1280,
#     'number': '631',
#     'name': 'PUFA 22:5 n-3 (DPA)',
#     'rank': 15200,
#     'unitName': 'g'},
#    'id': 13072555,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1272,
#     'number': '621',
#     'name': 'PUFA 22:6 n-3 (DHA)',
#     'rank': 15300,
#     'unitName': 'g'},
#    'id': 13072549,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1253,
#     'number': '601',
#     'name': 'Cholesterol',
#     'rank': 15700,
#     'unitName': 'mg'},
#    'id': 13072535,
#    'amount': 0.0},
#   {'nutrient': {'id': 2042,
#     'number': '500',
#     'name': 'Amino acids',
#     'rank': 16250,
#     'unitName': 'g'},
#    'type': 'FoodNutrient'},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1018,
#     'number': '221',
#     'name': 'Alcohol, ethyl',
#     'rank': 18200,
#     'unitName': 'g'},
#    'id': 13072497,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1057,
#     'number': '262',
#     'name': 'Caffeine',
#     'rank': 18300,
#     'unitName': 'mg'},
#    'id': 13072499,
#    'amount': 0.0},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1058,
#     'number': '263',
#     'name': 'Theobromine',
#     'rank': 18400,
#     'unitName': 'mg'},
#    'id': 13072500,
#    'amount': 0.0}],
#  'foodPortions': [{'id': 238330,
#    'portionDescription': '1 cup',
#    'gramWeight': 100.0,
#    'sequenceNumber': 2,
#    'modifier': '10205',
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'}},
#   {'id': 242214,
#    'portionDescription': '1 oz',
#    'gramWeight': 28.35,
#    'sequenceNumber': 4,
#    'modifier': '40000',
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'}},
#   {'id': 250342,
#    'portionDescription': '1 package',
#    'gramWeight': 50.0,
#    'sequenceNumber': 3,
#    'modifier': '61528',
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'}},
#   {'id': 250269,
#    'portionDescription': '1 nut',
#    'gramWeight': 1.5,
#    'sequenceNumber': 1,
#    'modifier': '61509',
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'}},
#   {'id': 263306,
#    'portionDescription': 'Quantity not specified',
#    'gramWeight': 28.0,
#    'sequenceNumber': 5,
#    'modifier': '90000',
#    'measureUnit': {'id': 9999,
#     'name': 'undetermined',
#     'abbreviation': 'undetermined'}}],
#  'dataType': 'Survey (FNDDS)'}

# %%
json_data.get("foodPortions")
# Out:
# [{'id': 238330,
#   'portionDescription': '1 cup',
#   'gramWeight': 100.0,
#   'sequenceNumber': 2,
#   'modifier': '10205',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 242214,
#   'portionDescription': '1 oz',
#   'gramWeight': 28.35,
#   'sequenceNumber': 4,
#   'modifier': '40000',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 250342,
#   'portionDescription': '1 package',
#   'gramWeight': 50.0,
#   'sequenceNumber': 3,
#   'modifier': '61528',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 250269,
#   'portionDescription': '1 nut',
#   'gramWeight': 1.5,
#   'sequenceNumber': 1,
#   'modifier': '61509',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 263306,
#   'portionDescription': 'Quantity not specified',
#   'gramWeight': 28.0,
#   'sequenceNumber': 5,
#   'modifier': '90000',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}}]

# %%
json_data.get("foodPortions")[0]["amount"]
# Out:
# 1.0

# %%
json_data.get("foodPortions")
# Out:
# [{'id': 240516,
#   'portionDescription': "1 cup, Butterfinger BB's",
#   'gramWeight': 174.0,
#   'sequenceNumber': 7,
#   'modifier': '10338',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 246554,
#   'portionDescription': '1 bar (2.16 oz)',
#   'gramWeight': 61.0,
#   'sequenceNumber': 4,
#   'modifier': '60379',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 246541,
#   'portionDescription': '1 bar (1.6 oz)',
#   'gramWeight': 45.0,
#   'sequenceNumber': 3,
#   'modifier': '60363',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 247729,
#   'portionDescription': '1 fun size bar',
#   'gramWeight': 21.0,
#   'sequenceNumber': 2,
#   'modifier': '60822',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 254300,
#   'portionDescription': "10 Butterfinger BB's",
#   'gramWeight': 26.0,
#   'sequenceNumber': 6,
#   'modifier': '63873',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 254290,
#   'portionDescription': '1 king size bar',
#   'gramWeight': 108.0,
#   'sequenceNumber': 5,
#   'modifier': '63862',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 256124,
#   'portionDescription': '1 miniature/bite size',
#   'gramWeight': 7.0,
#   'sequenceNumber': 1,
#   'modifier': '64233',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}},
#  {'id': 266832,
#   'portionDescription': 'Quantity not specified',
#   'gramWeight': 21.0,
#   'sequenceNumber': 8,
#   'modifier': '90000',
#   'measureUnit': {'id': 9999,
#    'name': 'undetermined',
#    'abbreviation': 'undetermined'}}]
